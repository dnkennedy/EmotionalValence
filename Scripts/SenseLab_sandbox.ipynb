# %% [markdown]
# # SenseLab Sandbox
# Playing around with [senselab](https://github.com/sensein/senselab)

# %%
# %pip install senselab

# %% [markdown]
# ## QuickStart

# %%
from senselab.audio.data_structures import Audio
from senselab.audio.tasks.preprocessing import resample_audios
from senselab.audio.tasks.features_extraction import extract_features_from_audios
from senselab.audio.tasks.speech_to_text import transcribe_audios
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from senselab.audio.data_structures import Audio
#       2 from senselab.audio.tasks.preprocessing import resample_audios
#       3 from senselab.audio.tasks.features_extraction import extract_features_from_audios
#
# ModuleNotFoundError: No module named 'senselab'
